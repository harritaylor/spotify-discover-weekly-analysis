# %%
import json

playlists = {}


data = json.load(open('response_1.json'))

# %%
# data['items'][0]['id']
for i in range(1,4):
    data = json.load(open('response_' + str(i) + '.json'))
    for i in range(len(data['items'])):
        p_name = data['items'][i]['name']
        p_id = data['items'][i]['id']
        playlists[p_name] = p_id

# %%
playlists
# Out:
# {'Alternative 70s': '37i9dQZF1DXb3ZjVksUlfu',
#  'Ambient Work': '6ga6kjePa3efh6nzUS13Jy',
#  'American Chill/2017': '1IHnOdY6GPqX3zfSZBtPJc',
#  'August 17': '25eWZK5gQPstY9BBDMbVO4',
#  'BBC 6 Music Recommends (BBC 6 Music)': '6ToRtiBeKUf0py8gZO6gQj',
#  'Dec 17': '5Nu8NbNGCYGusWVoPkCKQ7',
#  'Discover Weekly': '37i9dQZEVXcFtNY9lcMF44',
#  'Discover Weekly Archive': '3HEX70QFhM3XZiaSB3TgEx',
#  'Dub Reggae': '0s8tfHVdQa8duFMev3ZlgD',
#  'Feb 18': '3uO9U4MIOxymDOptPXp1Xo',
#  'Hip Hop/Rnb': '7pQUkuOagfL4l9Chnjzpus',
#  'Hippie Songs': '1Ovmq0mAjbzAtfN0EFf249',
#  'I, Tonya': '5NBxaIG62gFojqOeyO795R',
#  'Jan 18': '4FQuBxEwQ9XZVdEI3qRbvT',
#  'Jazzy ': '1gNxEBntf9LfUnZ4tgonOk',
#  'July 17': '3Y80H2AJYIB5cmBHusRuwg',
#  'Lazy Psychadelic': '1MM9EanaLmBJWTHL1V3Elc',
#  'Liked from Radio': '1ata5R8U5QLSmlji4v0dUD',
#  'Mar 18': '7bNfHYehkeBQVeBL6tYZti',
#  'Modern Psychedelia': '37i9dQZF1DX8gDIpdqp1XJ',
# ...

# %%
ignore_playlists = ["🌊", "sic ille manus", "mood",
                   "great western wail-ways ", "good vibes", "big",
                   "best", "Wicks - Brennan McDowell", "Villain",
                   "Sinnerman – Nina Simone", "Running",
                   "Motown | 2018 Playlist | Soul Music | Updated Weekly",
                   "Modern Psychedelia", "Lazy Psychadelic", "Jazzy ",
                   "I, Tonya", "Hippie Songs", "Hip Hop/Rnb", "Dub Reggae",
                   "Discover Weekly", "BBC 6 Music Recommends (BBC 6 Music)",
                   "American Chill/2017", "Ambient Work", "Alternative 70s"]

for n in ignore_playlists:
    del playlists[n]

# %%
playlists
# Out:
# {'August 17': '25eWZK5gQPstY9BBDMbVO4',
#  'Dec 17': '5Nu8NbNGCYGusWVoPkCKQ7',
#  'Discover Weekly Archive': '3HEX70QFhM3XZiaSB3TgEx',
#  'Feb 18': '3uO9U4MIOxymDOptPXp1Xo',
#  'Jan 18': '4FQuBxEwQ9XZVdEI3qRbvT',
#  'July 17': '3Y80H2AJYIB5cmBHusRuwg',
#  'Liked from Radio': '1ata5R8U5QLSmlji4v0dUD',
#  'Mar 18': '7bNfHYehkeBQVeBL6tYZti',
#  'November 2017': '11zPXzR9sZYsxHrnN3rpTb',
#  'October 17': '0NuekvJ6nYyKXVa2XyxE5h',
#  'September 17': '6dwTEPI0UQfQjjX33sV6Da',
#  'april 17': '2rQFIXyK5BYUWI71CYtlcZ',
#  'autumn 15': '07muYbcNrXIiVEgn91KsQC',
#  'autumn 16': '6YPS4yC4S7EqG3zx3nTccG',
#  'december 16': '4bdeXUosWmjm7cgrv4cC4U',
#  'february 17': '6nPEPxM80ZRf4xTbvpL0u4',
#  'january 17': '2dEqYuFbcHuU9VK8Hb6SMy',
#  'june 17': '5TdmCi3nDpdAsEHOXM68Np',
#  'march 17': '406hvHNxzcZYh0auNr83EU',
#  'may 17': '762dVWgPzDQYAvGeVqiLWU',
#  'spring 16': '65QJrwBlG3ojSprcykTNaO',
#  'summer 15': '06KOQNmTHzXnuzSygBcqz2',
#  'summer 16': '2bMJQUI9oK5BUJGZBoqNyI',
# ...

# %%
1152753071

# %%
items(added_at,track(id))

# %%
import requests
from tqdm import tqdm

headers = {
    'Accept': 'application/json',
    'Authorization': 'Bearer BQAHYoL-3zceqxGtGZa4qQy-xS5hbus5w9cBcSVixBaEHR9PAbrmr7XQRtYLysPk4eJymZ-yelFThnnr8wcHCjS0DgeMBcw7_ikgVjf7bjUt5mr57zQ1vaoqzGaLpMQFZgaWyNXM2ug4XiAXyXatx-5Rv09rpLtVThky9TLozsz0AQFxnZQdriZrV_xm8G-fHw4e6heSN_k7FtTa_bx2-rNqxi_Y2MpBd8Lcx2dl9_-u5eRaDrz0U355uGT584_bwYYMMiKX4JuRjw',
}

params = (
    ('fields', 'items(added_at,track(id))'),
)

# total: 1526

archive = []
i = 0
for i in tqdm(range(0,16)):
    offset = i*100
    response = requests.get('https://api.spotify.com/v1/users/1152753071/playlists/3HEX70QFhM3XZiaSB3TgEx/tracks?offset='+str(offset)+'&limit=100', headers=headers, params=params)
    
#     response.content

    for i in response.json()['items']:
        archive.append((i['track']['id'],i['added_at']))
#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://api.spotify.com/v1/users/1152753071/playlists/3HEX70QFhM3XZiaSB3TgEx/tracks?fields=items(added_at,track(id))', headers=headers)
# Out:
# 100%|██████████| 16/16 [00:02<00:00,  5.55it/s]

# %%
archive[1525]
# Out:
# ('7gTMsKyhm6vuUWoxRaFpsJ', '2018-03-12T01:54:34Z')

# %%
del playlists['Discover Weekly Archive']

# %%
liked_playlists = []
for i in playlists.values():
    liked_playlists.append(str(i))

# %%
liked_playlists
# Out:
# ['1ata5R8U5QLSmlji4v0dUD',
#  '7bNfHYehkeBQVeBL6tYZti',
#  '3uO9U4MIOxymDOptPXp1Xo',
#  '4FQuBxEwQ9XZVdEI3qRbvT',
#  '5Nu8NbNGCYGusWVoPkCKQ7',
#  '11zPXzR9sZYsxHrnN3rpTb',
#  '0NuekvJ6nYyKXVa2XyxE5h',
#  '6dwTEPI0UQfQjjX33sV6Da',
#  '25eWZK5gQPstY9BBDMbVO4',
#  '3Y80H2AJYIB5cmBHusRuwg',
#  '5TdmCi3nDpdAsEHOXM68Np',
#  '762dVWgPzDQYAvGeVqiLWU',
#  '2rQFIXyK5BYUWI71CYtlcZ',
#  '406hvHNxzcZYh0auNr83EU',
#  '6nPEPxM80ZRf4xTbvpL0u4',
#  '2dEqYuFbcHuU9VK8Hb6SMy',
#  '4bdeXUosWmjm7cgrv4cC4U',
#  '6YPS4yC4S7EqG3zx3nTccG',
#  '2bMJQUI9oK5BUJGZBoqNyI',
#  '65QJrwBlG3ojSprcykTNaO',
#  '1W2IXBgY1xLGMfpcnAaQEB',
#  '07muYbcNrXIiVEgn91KsQC',
#  '06KOQNmTHzXnuzSygBcqz2']

# %%
liked_playlists
# Out:
# ['1ata5R8U5QLSmlji4v0dUD',
#  '7bNfHYehkeBQVeBL6tYZti',
#  '3uO9U4MIOxymDOptPXp1Xo',
#  '4FQuBxEwQ9XZVdEI3qRbvT',
#  '5Nu8NbNGCYGusWVoPkCKQ7',
#  '11zPXzR9sZYsxHrnN3rpTb',
#  '0NuekvJ6nYyKXVa2XyxE5h',
#  '6dwTEPI0UQfQjjX33sV6Da',
#  '25eWZK5gQPstY9BBDMbVO4',
#  '3Y80H2AJYIB5cmBHusRuwg',
#  '5TdmCi3nDpdAsEHOXM68Np',
#  '762dVWgPzDQYAvGeVqiLWU',
#  '2rQFIXyK5BYUWI71CYtlcZ',
#  '406hvHNxzcZYh0auNr83EU',
#  '6nPEPxM80ZRf4xTbvpL0u4',
#  '2dEqYuFbcHuU9VK8Hb6SMy',
#  '4bdeXUosWmjm7cgrv4cC4U',
#  '6YPS4yC4S7EqG3zx3nTccG',
#  '2bMJQUI9oK5BUJGZBoqNyI',
#  '65QJrwBlG3ojSprcykTNaO',
#  '1W2IXBgY1xLGMfpcnAaQEB',
#  '07muYbcNrXIiVEgn91KsQC']

# %%
OAuth_Token = 'BQAHYoL-3zceqxGtGZa4qQy-xS5hbus5w9cBcSVixBaEHR9PAbrmr7XQRtYLysPk4eJymZ-yelFThnnr8wcHCjS0DgeMBcw7_ikgVjf7bjUt5mr57zQ1vaoqzGaLpMQFZgaWyNXM2ug4XiAXyXatx-5Rv09rpLtVThky9TLozsz0AQFxnZQdriZrV_xm8G-fHw4e6heSN_k7FtTa_bx2-rNqxi_Y2MpBd8Lcx2dl9_-u5eRaDrz0U355uGT584_bwYYMMiKX4JuRjw'

headers = {
    'Accept': 'application/json',
    'Authorization': 'Bearer ' + OAuth_Token,
}

params = (
    ('fields', 'items(added_at,track(id))'),
)

# total: 1526

liked_songs = []

playlist_id = '06KOQNmTHzXnuzSygBcqz2'
response = requests.get('https://api.spotify.com/v1/users/1152753071/playlists/' + playlist_id + '/tracks?offset=0&limit=100', headers=headers, params=params)

for i in response.json()['items']:
    liked_songs.append((i['track']['id'],i['added_at']))
    
response = requests.get('https://api.spotify.com/v1/users/1152753071/playlists/' + playlist_id + '/tracks?offset=100&limit=100', headers=headers, params=params)

for i in response.json()['items']:
    liked_songs.append((i['track']['id'],i['added_at']))


for playlist_id in liked_playlists:
        response = requests.get('https://api.spotify.com/v1/users/1152753071/playlists/' + playlist_id + '/tracks?offset=0&limit=100', headers=headers, params=params)

        for i in response.json()['items']:
            liked_songs.append((i['track']['id'],i['added_at']))

# %%
archive
# Out:
# [('2TTAPkrGQQOZkaUTUlt21Q', '2016-09-26T07:09:57Z'),
#  ('0KBjFrKkWhJMjdLX1wBgzg', '2016-09-26T07:09:58Z'),
#  ('6IVIsIJXFUxyyG2Bp2AEaq', '2016-09-26T07:09:58Z'),
#  ('754cLTbgHNJDIKDxjDsMkI', '2016-09-26T07:09:59Z'),
#  ('3acQT3MMEyZgWKRChD92W3', '2016-09-26T07:10:00Z'),
#  ('3exgW5tkROeKtsA1oglTCU', '2016-09-26T07:10:01Z'),
#  ('2hMNP81ebBKjVs3D7CMG3p', '2016-09-26T07:10:01Z'),
#  ('3IxTzXsvEeKmVDewO5Gqp9', '2016-09-26T07:10:02Z'),
#  ('3c0phV53oxoCUmpuFkBUgU', '2016-09-26T07:10:03Z'),
#  ('1K5wIDgNBgT7lVOMibiRAE', '2016-09-26T07:10:04Z'),
#  ('70LIe5IYE2TI8qqxePAoOR', '2016-09-26T07:19:14Z'),
#  ('0DuuEawKZv0CaPpojnMciU', '2016-09-26T07:19:16Z'),
#  ('4dUOAFN1Yk2TuslROwZcdX', '2016-09-26T07:19:21Z'),
#  ('0cF4mPq0ySXYCH7m46jAEj', '2016-09-26T07:19:25Z'),
#  ('4wcCoYcwExlzVeGMFDDGA3', '2016-09-26T07:19:33Z'),
#  ('49j1UwCxDAO3GIyREYScJ6', '2016-09-26T07:59:16Z'),
#  ('5adZJgLKDMlZGDBsVIKVML', '2016-09-26T07:59:18Z'),
#  ('6GXHs5QcBswJnoC5IoZ9lp', '2016-09-26T07:59:20Z'),
# ...

# %%
liked_songs
# Out:
# [('32ZeITs3JUlf0zGB8zS3cO', '2015-05-25T15:37:18Z'),
#  ('43aOGDeF6L2MOuXtJX5fu8', '2015-05-25T15:38:24Z'),
#  ('2cjQdVcuTteaz44I0Cjs4f', '2015-05-25T15:39:27Z'),
#  ('4mS1Su5zf50QwNcjYjYzG6', '2015-05-25T15:40:40Z'),
#  ('3WDRFFmZg9YEwMsNIty1ht', '2015-05-25T15:41:24Z'),
#  ('0sWrJaH7ues8yOlczcK71l', '2015-05-25T15:43:00Z'),
#  ('4jEzyMsPcQr7LQG6J0vp3V', '2015-06-09T11:12:35Z'),
#  ('3BiZ8inbHGmvmOmLMFNXYn', '2015-06-09T11:13:20Z'),
#  ('7akxzzetf06jvqQEEIf55y', '2015-06-09T11:13:45Z'),
#  ('7fQgIaTVHxip9m7no6wwAc', '2015-06-09T11:13:58Z'),
#  ('72cjVO7D8QF2DgkafXq9it', '2015-06-09T11:14:19Z'),
#  ('5DPbd8DX8iqVcLwSHEMYmT', '2015-06-09T11:14:42Z'),
#  ('3dzW0SoVNyJTWWJimX8stj', '2015-06-09T11:14:54Z'),
#  ('1Otek5aO69cfFGeB3jfmRE', '2015-06-09T11:15:09Z'),
#  ('0A4PZuepTcIQVvA5m7R0M1', '2015-06-09T11:15:18Z'),
#  ('0B1zVsLqmV9ibIFdNS5tGs', '2015-06-09T11:15:41Z'),
#  ('7b16g1E6OAG6HNmAQBgZos', '2015-06-09T11:16:18Z'),
#  ('0bHm2wFL0m7qZIlhO7PQu5', '2015-06-09T11:16:25Z'),
# ...

# %%
liked_songs_ids =

# %%
liked_songs_string = ",".join([i[0] for i in liked_songs])

# %%
type(liked_songs_string)
# Out:
# str

# %%
len(liked_songs)
# Out:
# 737

# %%
with open('liked_songs.csv','w') as file:
    for i in liked_songs:
        line = i[0] + ', ' + i[1]
        file.write(line)
        file.write('\n')

with open('discover_weekly.csv','w') as file:
    for i in archive:
        line = i[0] + ', ' + i[1]
        file.write(line)
        file.write('\n')

# %%
for i in range(0,14):
    print(i*50)
    print((i*50)+49)
# Out:
# 0
# 49
# 50
# 99
# 100
# 149
# 150
# 199
# 200
# 249
# 250
# 299
# 300
# 349
# 350
# 399
# 400
# 449
# 450
# 499
# 500
# 549
# 550
# 599
# 600
# 649
# 650
# 699

# %%
import requests

headers = {
    'Accept': 'application/json',
    'Authorization': 'Bearer BQCJ-8wdU4U4N0FJxJqn1p6L8J9qxfXQYBrvWyOkHDNzDysHq-VQnQmi9z3nXck51y-ZlNtonCrQHxFnA3592WZinnNgYun4ZMfpAp6mmC5bi9C6iCyMkHMZo5OKENXBZwGbqMWo0IIYGpEXpULgakXpZe8B1ivY1yOkU1PXbxBDeftnk7hUOQqbxheTsgigR7ZmocYKQ6SU3-SDifVeNhIwDNCfHUuov0tYcZ5htE5PzC13ZV9PQUnu80Y_pIiP3g2QZyWZn8H87g',
}

liked_audio_features = []

for i in range(0,14):
    liked_songs_string = ",".join(j[0] for j in liked_songs[(i*50):(i*50)+49])
    
    params = (
        ('ids', liked_songs_string),
    )
    response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)

    for x in response.json()['audio_features']:
        liked_audio_features.append(x)

# %%
i = 0
for j in range(7):
    print("Start %d, end %d" % (i,i+100))
    i+=100
# Out:
# Start 0, end 100
# Start 100, end 200
# Start 200, end 300
# Start 300, end 400
# Start 400, end 500
# Start 500, end 600
# Start 600, end 700

# %%
liked_audio_features = []

i = 0
for j in range(7):
    liked_songs_string = ",".join([i[0] for i in liked_songs[i:i+100]])
    params = (
        ('ids', liked_songs_string),
    )
    response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)
    audio_features = response.json()['audio_features']
    for y in audio_features:
        liked_audio_features.append(y)
    i += 100


liked_songs_string = ",".join([i[0] for i in liked_songs[i:i+100]])
print(len(liked_audio_features))
# Out:
# 700

# %%
liked_audio_features[1]
# Out:
# {'acousticness': 0.104,
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43aOGDeF6L2MOuXtJX5fu8',
#  'danceability': 0.808,
#  'duration_ms': 187725,
#  'energy': 0.907,
#  'id': '43aOGDeF6L2MOuXtJX5fu8',
#  'instrumentalness': 0.000735,
#  'key': 1,
#  'liveness': 0.216,
#  'loudness': -4.028,
#  'mode': 0,
#  'speechiness': 0.0609,
#  'tempo': 127.978,
#  'time_signature': 4,
#  'track_href': 'https://api.spotify.com/v1/tracks/43aOGDeF6L2MOuXtJX5fu8',
#  'type': 'audio_features',
#  'uri': 'spotify:track:43aOGDeF6L2MOuXtJX5fu8',
#  'valence': 0.943}

# %%
liked_audio_features_list = []

header = ""

for x in liked_audio_features[0]:
    header += x + ", "
header = header[:-2]

liked_audio_features_list.append(header)

# %%
for i in liked_audio_features:
    line = ""
    for j in i:
        line += str(i[j]) + ", "
    line = line[:-2]
    
    liked_audio_features_list.append(line)

# %%
len(liked_audio_features_list)

import csv

with open('liked_audio_features.csv','w') as f:
    for line in liked_audio_features_list:
        f.write("%s\n" % line)

# %%
import json

# j = json.dumps(liked_audio_features)
# j

with open('liked_audio_features.json','w') as fp:
    json.dump(liked_audio_features, fp)

# %%
liked_songs_string = ",".join([i[0] for i in liked_songs[700:738]])
params = (
    ('ids', liked_songs_string),
)
response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)
audio_features = response.json()['audio_features']
for y in audio_features:
        liked_audio_features.append(y)

print(len(liked_audio_features))
# Out:
# 737

# %%
# first 37
liked_songs_string = ",".join([i[0] for i in liked_songs[0:36]])
params = (
    ('ids', liked_songs_string),
)
response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)
audio_features = response.json()['audio_features']

# %%
x = []
for i in audio_features:
    x.append(i)

# %%
x
# Out:
# [{'acousticness': 0.108,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/32ZeITs3JUlf0zGB8zS3cO',
#   'danceability': 0.547,
#   'duration_ms': 241985,
#   'energy': 0.695,
#   'id': '32ZeITs3JUlf0zGB8zS3cO',
#   'instrumentalness': 0.00301,
#   'key': 9,
#   'liveness': 0.14,
#   'loudness': -4.969,
#   'mode': 1,
#   'speechiness': 0.0337,
#   'tempo': 144.684,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/32ZeITs3JUlf0zGB8zS3cO',
#   'type': 'audio_features',
#   'uri': 'spotify:track:32ZeITs3JUlf0zGB8zS3cO',
#   'valence': 0.641},
#  {'acousticness': 0.104,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43aOGDeF6L2MOuXtJX5fu8',
#   'danceability': 0.808,
#   'duration_ms': 187725,
#   'energy': 0.907,
#   'id': '43aOGDeF6L2MOuXtJX5fu8',
#   'instrumentalness': 0.000735,
#   'key': 1,
#   'liveness': 0.216,
#   'loudness': -4.028,
#   'mode': 0,
#   'speechiness': 0.0609,
#   'tempo': 127.978,
#   'time_signature': 4,
# ...

# %%
i = 37
for j in range(1,8):
    print("start: %d, end: %d" % (i,37+(j*100)-1))
    i += 100
# Out:
# start: 37, end: 136
# start: 137, end: 236
# start: 237, end: 336
# start: 337, end: 436
# start: 437, end: 536
# start: 537, end: 636
# start: 637, end: 736

# %%
len(archive)
# Out:
# 1526

# %%
i = 0
for j in range(15):
    print("Start %d, end %d" % (i,i+100))
    i+=100
# Out:
# Start 0, end 100
# Start 100, end 200
# Start 200, end 300
# Start 300, end 400
# Start 400, end 500
# Start 500, end 600
# Start 600, end 700
# Start 700, end 800
# Start 800, end 900
# Start 900, end 1000
# Start 1000, end 1100
# Start 1100, end 1200
# Start 1200, end 1300
# Start 1300, end 1400
# Start 1400, end 1500

# %%
archive_audio_features = []

i = 0
for j in range(15):
    liked_songs_string = ",".join([i[0] for i in archive[i:i+100]])
    params = (
        ('ids', liked_songs_string),
    )
    response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)
    audio_features = response.json()['audio_features']
    for y in audio_features:
        archive_audio_features.append(y)
    i += 100



print(len(archive_audio_features))
# Out:
# 1500

# %%
headers = {
    'Accept': 'application/json',
    'Authorization': 'Bearer BQCJ-8wdU4U4N0FJxJqn1p6L8J9qxfXQYBrvWyOkHDNzDysHq-VQnQmi9z3nXck51y-ZlNtonCrQHxFnA3592WZinnNgYun4ZMfpAp6mmC5bi9C6iCyMkHMZo5OKENXBZwGbqMWo0IIYGpEXpULgakXpZe8B1ivY1yOkU1PXbxBDeftnk7hUOQqbxheTsgigR7ZmocYKQ6SU3-SDifVeNhIwDNCfHUuov0tYcZ5htE5PzC13ZV9PQUnu80Y_pIiP3g2QZyWZn8H87g',
}

liked_songs_string = ",".join([i[0] for i in archive[1500:1527]])
params = (
    ('ids', liked_songs_string),
)
response = requests.get('https://api.spotify.com/v1/audio-features', headers=headers, params=params)
print(response)
audio_features = response.json()['audio_features']
for y in audio_features:
        archive_audio_features.append(y)

print(len(archive_audio_features))
# Out:
# <Response [200]>
# 1526

# %%
arch_audio_features_list = []

header = ""ive

for x in liked_audio_features[0]:
    header += x + ", "
header = header[:-2]

liked_audio_features_list.append(header)
